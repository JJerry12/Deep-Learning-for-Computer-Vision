# %% [markdown]
# # Semantic Segmentation (YOLO8)

# %%
# !pip install ultralytics
# !pip install opencv-python-headless==4.5.5.64 #在windows環境若出現問題，安裝這行指令
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 529.2/529.2 kB 11.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 198.8/198.8 kB 14.5 MB/s eta 0:00:00
# ...

# %% [markdown]
# ## 載入套件

# %%
from ultralytics import YOLO

# %% [markdown]
# ## 載入模型

# %%
model = YOLO("./yolov8n-seg.pt")
# Out:
# ...
# 100%|██████████| 6.73M/6.73M [00:00<00:00, 108MB/s]

# %%
from google.colab import files
files.upload();
# !unzip YOLO8_images.zip -d . #解壓縮
# Out:
#      <input type="file" id="files-9f8caffb-1740-4635-9cb5-ab9ca19c6adc" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9f8caffb-1740-4635-9cb5-ab9ca19c6adc">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# ## 圖片/影片辨識

# %%
# 預測
results = model("./segmentation.jpg")

# 顯示物件類別
print(results[0].boxes.cls)
print()

# 顯示物件座標
print(results[0].boxes.xyxy)
# Out:
# image 1/1 /content/segmentation.jpg: 480x640 29 cars, 1 truck, 553.3ms
# Speed: 2.5ms preprocess, 553.3ms inference, 182.4ms postprocess per image at shape (1, 3, 640, 640)
# tensor([2., 2., 2., 2., 2., 2., 2., 2., 7., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2., 2.])
#
# tensor([[ 11.4035, 244.0294,  96.9108, 291.6265],
#         [591.1646, 338.0679, 680.5969, 428.8355],
#         [528.0887, 169.8964, 569.5262, 206.7237],
#         [436.8091, 467.5925, 548.5085, 532.1855],
#         [540.8065, 116.6434, 571.4212, 141.4594],
#         [639.6070, 240.6268, 704.6263, 301.1908],
#         [635.1156, 107.1774, 665.1729, 131.9963],
#         [154.2809, 158.8541, 200.2080, 192.9265],
#         [139.5404, 202.8158, 236.9119, 291.8210],
#         [602.8750,  75.2131, 623.0481,  93.2411],
#         [120.6289, 202.6151, 161.4336, 241.9952],
#         [579.2123,  86.7600, 604.4741, 111.0932],
#         [217.2738, 154.8951, 265.6425, 190.5051],
# ...

# %% [markdown]
# ## webcam/整個目錄辨識

# %%
# webcam
# results = model.predict(source="0")
# 整個目錄
# results = model.predict(source="folder", show=True)

# %% [markdown]
# ## 顯示偵測結果

# %%
# save=True：存檔
from PIL import Image

im1 = Image.open("./segmentation.jpg")
results = model.predict(source=im1, save=True)
# Out:
# 0: 480x640 29 cars, 1 truck, 629.4ms
# Speed: 13.9ms preprocess, 629.4ms inference, 150.7ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/segment/predict

# %%
ls ./runs/segment/predict/
# Out:
# segmentation.jpg

# %%
from IPython.display import Image
Image('./runs/segment/predict/segmentation.jpg')
